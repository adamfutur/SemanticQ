# %% [markdown]
# # BERT Training - Bloom's Taxonomy Classifier
#
# Fine-tune BERT for educational question classification.
#
# **Requirements:** GPU recommended for faster training.

# %%
# IMPORTANT: Disable TensorFlow to avoid dependency conflicts
import os
os.environ['USE_TF'] = '0'
os.environ['USE_TORCH'] = '1'
os.environ['TRANSFORMERS_NO_TF'] = '1'

# %%
import sys

# Navigate to project root (parent of notebooks folder)
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

# Add src to path
if 'src' not in sys.path and os.path.exists('src'):
    sys.path.insert(0, 'src')

print(f'Working directory: {os.getcwd()}')
# Out:
# Working directory: c:\Users\MSI\Desktop\FastText

# %%
import torch
import pandas as pd

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
else:
    print('Running on CPU (training will be slower)')
# Out:
# PyTorch version: 2.9.1+cpu
# CUDA available: False
# Running on CPU (training will be slower)

# %%
from preprocessing import load_and_preprocess_data, load_config
from bert_classifier import SemanticBERT, train_bert_model
from evaluate import ModelEvaluator, evaluate_bert_model

print('Modules imported successfully!')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1778, in _LazyModule._get_module(self, module_name)
#    1777 try:
# -> 1778     return importlib.import_module("." + module_name, self.__name__)
#    1779 except Exception as e:
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\bert\modeling_bert.py:47
#      36 from ...modeling_outputs import (
#      37     BaseModelOutputWithPastAndCrossAttentions,
#      38     BaseModelOutputWithPoolingAndCrossAttentions,
#    (...)
#      45     TokenClassifierOutput,
#      46 )
# ---> 47 from ...modeling_utils import PreTrainedModel
#      48 from ...pytorch_utils import apply_chunking_to_forward, find_pruneable_heads_and_indices, prune_linear_layer
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\modeling_utils.py:48
#      47 from .integrations import PeftAdapterMixin, deepspeed_config, is_deepspeed_zero3_enabled
# ---> 48 from .loss.loss_utils import LOSS_MAPPING
#      49 from .pytorch_utils import (  # noqa: F401
#      50     Conv1D,
#      51     apply_chunking_to_forward,
#    (...)
#      57     prune_linear_layer,
#      58 )
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\loss\loss_utils.py:19
#      17 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 19 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      20 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\loss\loss_deformable_detr.py:4
#       2 import torch.nn as nn
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\image_transforms.py:50
#      49 if is_tf_available():
# ---> 50     import tensorflow as tf
#      52 if is_flax_available():
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\__init__.py:54
#      53 from tensorflow._api.v2 import bitwise
# ---> 54 from tensorflow._api.v2 import compat
#      55 from tensorflow._api.v2 import config
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\compat\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:32
#      31 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 32 from tensorflow._api.v2.compat.v1 import compat
#      33 from tensorflow._api.v2.compat.v1 import config
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.compat import v1
#       9 from tensorflow._api.v2.compat.v1.compat import v2
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py:49
#      48 from tensorflow._api.v2.compat.v1 import linalg
# ---> 49 from tensorflow._api.v2.compat.v1 import lite
#      50 from tensorflow._api.v2.compat.v1 import logging
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\compat\v1\lite\__init__.py:9
#       8 from tensorflow._api.v2.compat.v1.lite import constants
# ----> 9 from tensorflow._api.v2.compat.v1.lite import experimental
#      10 from tensorflow.lite.python.convert import OpsSet # line: 169
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.lite.experimental import authoring
#       9 from tensorflow.lite.python.analyzer import ModelAnalyzer as Analyzer # line: 35
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\authoring\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow.lite.python.authoring.authoring import compatible # line: 265
#      10 from tensorflow.python.util import module_wrapper as _module_wrapper
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\lite\python\authoring\authoring.py:43
#      42 # pylint: disable=g-import-not-at-top
# ---> 43 from tensorflow.lite.python import convert
#      44 from tensorflow.lite.python import lite
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\lite\python\convert.py:29
#      28 from tensorflow.lite.python import lite_constants
# ---> 29 from tensorflow.lite.python import util
#      30 from tensorflow.lite.python import wrap_toco
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\lite\python\util.py:51
#      50 try:
# ---> 51   from jax import xla_computation as _xla_computation
#      52 except ImportError:
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\jax\__init__.py:37
#      36 # Force early import, allowing use of `jax.core` after importing `jax`.
# ---> 37 import jax.core as _core
#      38 del _core
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\jax\core.py:18
#       1 # Copyright 2022 The JAX Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      15 # Note: import <name> as <name> is required for names to be exported.
#      16 # See PEP 484 & https://github.com/jax-ml/jax/issues/7570
# ---> 18 from jax._src.core import (
#      19   AbstractToken as AbstractToken,
#      20   AbstractValue as AbstractValue,
#      21   Atom as Atom,
#      22   CallPrimitive as CallPrimitive,
#      23   DebugInfo as DebugInfo,
#      24   DShapedArray as DShapedArray,
#      25   DropVar as DropVar,
#      26   Effect as Effect,
#      27   Effects as Effects,
#      28   get_opaque_trace_state as get_opaque_trace_state,
#      29   InconclusiveDimensionOperation as InconclusiveDimensionOperation,
#      30   JaxprPpContext as JaxprPpContext,
#      31   JaxprPpSettings as JaxprPpSettings,
#      32   JaxprTypeError as JaxprTypeError,
#      33   nonempty_axis_env as nonempty_axis_env_DO_NOT_USE,  # noqa: F401
#      34   OutputType as OutputType,
#      35   ParamDict as ParamDict,
#      36   ShapedArray as ShapedArray,
#      37   Trace as Trace,
#      38   Tracer as Tracer,
#      39   unsafe_am_i_under_a_jit as unsafe_am_i_under_a_jit_DO_NOT_USE,  # noqa: F401
#      40   unsafe_am_i_under_a_vmap as unsafe_am_i_under_a_vmap_DO_NOT_USE,  # noqa: F401
#      41   unsafe_get_axis_names as unsafe_get_axis_names_DO_NOT_USE,  # noqa: F401
#      42   UnshapedArray as UnshapedArray,
#      43   Value as Value,
#      44   abstract_token as abstract_token,
#      45   aval_mapping_handlers as aval_mapping_handlers,
#      46   call as call,
#      47   call_impl as call_impl,
#      48   check_jaxpr as check_jaxpr,
#      49   concrete_or_error as concrete_or_error,
#      50   concretization_function_error as concretization_function_error,
#      51   custom_typechecks as custom_typechecks,
#      52   ensure_compile_time_eval as ensure_compile_time_eval,
#      53   eval_context as eval_context,
#      54   eval_jaxpr as eval_jaxpr,
#      55   find_top_trace as find_top_trace,
#      56   gensym as gensym,
#      57   get_aval as get_aval,
#      58   is_concrete as is_concrete,
#      59   is_constant_dim as is_constant_dim,
#      60   is_constant_shape as is_constant_shape,
#      61   jaxprs_in_params as jaxprs_in_params,
#      62   literalable_types as literalable_types,
#      63   mapped_aval as mapped_aval,
#      64   max_dim as max_dim,
#      65   min_dim as min_dim,
#      66   new_jaxpr_eqn as new_jaxpr_eqn,
#      67   no_axis_name as no_axis_name,
#      68   no_effects as no_effects,
#      69   primal_dtype_to_tangent_dtype as primal_dtype_to_tangent_dtype,
#      70   pytype_aval_mappings as pytype_aval_mappings,
#      71   set_current_trace as set_current_trace,
#      72   subjaxprs as subjaxprs,
#      73   take_current_trace as take_current_trace,
#      74   trace_ctx as trace_ctx,
#      75   TraceTag as TraceTag,
#      76   traverse_jaxpr_params as traverse_jaxpr_params,
#      77   unmapped_aval as unmapped_aval,
#      78   valid_jaxtype as valid_jaxtype,
#      79 )
#      82 from jax._src import core as _src_core
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\jax\_src\core.py:38
#      37 from jax._src import deprecations
# ---> 38 from jax._src import dtypes
#      39 from jax._src import config
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\jax\_src\dtypes.py:93
#      92 # fp8 support
# ---> 93 float8_e3m4: type[np.generic] = ml_dtypes.float8_e3m4
#      94 float8_e4m3: type[np.generic] = ml_dtypes.float8_e4m3
#
# AttributeError: module 'ml_dtypes' has no attribute 'float8_e3m4'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 2
#       1 from preprocessing import load_and_preprocess_data, load_config
# ----> 2 from bert_classifier import SemanticBERT, train_bert_model
#       3 from evaluate import ModelEvaluator, evaluate_bert_model
#       5 print('Modules imported successfully!')
#
# File c:\Users\MSI\Desktop\FastText\src\bert_classifier.py:20
#      18 from torch.utils.data import DataLoader
#      19 from tqdm import tqdm
# ---> 20 from transformers import (
#      21     BertForSequenceClassification,
#      22     BertTokenizer,
#      23     get_linear_schedule_with_warmup,
#      24 )
#      26 from dataset import BertDataset
#      29 def load_config(config_path: str = "config/config.yaml") -> dict:
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1767, in _LazyModule.__getattr__(self, name)
#    1765 elif name in self._class_to_module.keys():
#    1766     module = self._get_module(self._class_to_module[name])
# -> 1767     value = getattr(module, name)
#    1768 elif name in self._modules:
#    1769     value = self._get_module(name)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1766, in _LazyModule.__getattr__(self, name)
#    1764     value = Placeholder
#    1765 elif name in self._class_to_module.keys():
# -> 1766     module = self._get_module(self._class_to_module[name])
#    1767     value = getattr(module, name)
#    1768 elif name in self._modules:
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1780, in _LazyModule._get_module(self, module_name)
#    1778     return importlib.import_module("." + module_name, self.__name__)
#    1779 except Exception as e:
# -> 1780     raise RuntimeError(
#    1781         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1782         f" traceback):\n{e}"
#    1783     ) from e
#
# RuntimeError: Failed to import transformers.models.bert.modeling_bert because of the following error (look up to see its traceback):
# module 'ml_dtypes' has no attribute 'float8_e3m4'

# %%
# Load configuration
config = load_config('config/config.yaml')

# Load and preprocess data
train_df, val_df, test_df, label_to_id, id_to_label = load_and_preprocess_data(
    'data/raw/bloom_questions.csv',
    text_column='question',
    label_column='level',
    config_path='config/config.yaml'
)

print(f'Classes: {list(label_to_id.keys())}')
print(f'Train: {len(train_df)}, Val: {len(val_df)}, Test: {len(test_df)}')

# %%
# Training config - reduce for faster training
config['bert']['epochs'] = 3
config['bert']['batch_size'] = 8

print('Training config:')
print(f"  Epochs: {config['bert']['epochs']}")
print(f"  Batch size: {config['bert']['batch_size']}")

# %%
# Train BERT model
print('Starting BERT training...')

model = train_bert_model(
    train_df,
    val_df,
    label_to_id,
    config,
    save_dir='models/bert'
)

print('Training complete!')

# %%
# Evaluate on test set
labels = ['Remember', 'Understand', 'Apply', 'Analyze', 'Evaluate', 'Create']
evaluator = ModelEvaluator(labels)

metrics = evaluate_bert_model(model, test_df, evaluator)
evaluator.print_results('Semantic-BERT')

# %%
# Plot confusion matrix
evaluator.plot_confusion_matrix('Semantic-BERT', figsize=(10, 8))

# %%
# Test predictions
test_questions = [
    'What is the capital of France?',
    'Explain how photosynthesis works.',
    'Calculate the area of a circle.',
    'Compare democracy and monarchy.',
    'Evaluate the effectiveness of vaccines.',
    'Design an experiment to test gravity.'
]

for q in test_questions:
    result = model.predict_single(q)
    print(f"[{result['level']:12}] ({result['confidence']:5.0%}) {q}")
